# %% [markdown]
# ## Tools
# - Huggings face
# - Tensorflow
# - ONNx
# - W&B for build and deplyomnet

# %% [markdown]
# # Applications
# - Self driving cars
# - Farmars can easily count the number of animals they have
# - Mobile face recognization
# - Hospitals automate operations assisments

# %% [markdown]
# ## Learnings
# 1. tesors and variables
#     - Basics
#     - Initialization and cating
#     - indexing
#     - Maths operation
#     - Linear algebra operation
#     - common tensorflow functions
#     - Ragged tensors
#     - Saparse Tensors
#     - String tensors
#     - Variables
#     - Loading and saving models in tensorflow
# 2. Building a neural network with tensorflow (Car price prediction)
#     - Task understanding
#     - Data preparation
#     - Linear Regression model
#     - Error sanctioniing
#     - Training and optimazation
#     - Performance measurement
#     - VAlidation and testing
#     - Corrective measures
#
# 3. Building a neural network with tensorflow (Maleria diagnosis)
#     - Task Undersanding
#     - Data preparation
#     - Data Visualization
#     - Data Processing
#     - How and why Any neural Networks work
#     - Building ConvNets with Tesnorflow
#     - Binary crossentropy loss
#     - Training ConvNets
#     - Model Evaluation and Testing
#     - Loading and saving Tensorflow model to gdrive
# 4. Building more advance neural network with tensorflow (Maleria diagnosis)
#     - Task Undersanding
#     - Data preparation
#     - Data Visualization
#
# 5. Evaluating Classification models
#     - Precision, Recall, accuracy
#     - Cnnfusion matrix
#     - ROC curve
#
# 6. Improving the model performance
#     - Tensorflow callbacks
#     - Learning rate scheduling
#     - Model check points
#     - Mitigating Overfiting and Overfiting
#
# 7. Data Augmentation (Maleria diagnosis)
#     - Data augmentation with tf.Image
#     - Data augmentation with Keras Layers
#     - Mixup Augmentation
#     - Cutmix Augmentation
#     - Albumentation
#
# 8. Advance tensorflow
#     - Custom loss and matrix
#     - Eager and graph model
#     - Custom training loops
#
# 9. Tensoboard Integrartion
#     - Data Logging
#     - View model graph
#     - Hyperparameter Tuning
#     - Profiling and Visualization
#
# 10. MlOps with Weights and Biases (Maleria diagnosis)
#     - Experiment Tracking
#     - Hyperparameter Tuning
#     - Dataset Versioning
#
# 11. Human EMotions detection
#     - Data preparation
#     - Modeling and training
#     - Data Augmentation
#     - tensorflow records
#
# 12. Modern COnvolutional Neural Networks (Human EMotions detection )
#     - AlexNet
#     - VGNet
#     - ResNet
#     - Coding resNet from scratch
#     - MobileNet
#     - EfficientNet
#
# 13. Transfer Learning (Human EMotions detection )
#     - Feature Detection
#     - Finetuning
#
# 14. Understanding The blackBox (Human EMotions detection )
#     - Visualizing the intermediate Layers
#     - Grad-cam Methods
#
# 15. Class imbalance and Ensambling
#     - Ensembling
#
# 16. Transformers in vision (VIT)
#     - Understanding VITs
#     - Building VITs from Sscratch
#     - Finetuning the Huggingface VITs
#     - Model evaluation with Wandb
#     - Data Efficient Transformers
#     - Swin Transformers
#
# 17. Model Deployment (Human EMotions detection )
#
# 18. Object detection with YOLO
#
# 19. Image generation
