# %% [markdown]
# ## random numbers

# %%
import numpy as np
from numpy import random

# %%
x = random.randint(0,100)   # random integer
print(x)

x = random.rand()  # random float
print(x)
# Out:
# 66
# 0.31832585729590734

# %%
# create random array 
x=random.randint(100, size=(5))
print(x)
# Out:
# [33 86 31 63 96]

# %%
x = random.randint(100, size=(3, 5))
print(x)
# Out:
# [[22 71 44 79 70]
#  [23 11 58 93 16]
#  [16 40  7 69 58]]

# %%
x = random.rand(5)
print(x)
# Out:
# [0.42731714 0.19473582 0.44998438 0.3885237  0.22901655]

# %% [markdown]
#     The choice() method takes an array as a parameter and randomly returns one of the values.

# %%
x = random.choice([2,8,9,3])
print(x)
# Out:
# 2

# %%
x = random.choice([3, 5, 7, 9], size=(3, 5))
print(x)
# Out:
# [[9 9 3 3 5]
#  [3 9 7 9 7]
#  [3 9 5 5 9]]

# %% [markdown]
# ## choosing values with some probability distrubution

# %%
x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(100))
print(x)
# Out:
# [7 3 5 7 7 7 7 7 5 7 3 7 5 7 3 7 7 5 5 5 5 3 7 5 5 5 5 7 5 7 5 7 7 5 7 7 7
#  7 7 7 5 7 7 3 5 7 3 5 7 5 5 5 3 7 3 5 7 3 3 5 7 7 5 5 7 7 7 7 5 7 7 5 5 5
#  5 5 7 7 5 5 7 5 5 7 5 7 7 7 7 5 7 7 7 7 5 5 5 7 5 7]

# %%
n = np.where(x == 7)
print(np.array(n))
# Out:
# [[ 0  3  4  5  6  7  9 11 13 15 16 22 27 29 31 32 34 35 36 37 38 39 41 42
#   45 48 53 56 60 61 64 65 66 67 69 70 76 77 80 83 85 86 87 88 90 91 92 93
#   97 99]]

# %%
x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(3, 5))

print(x)
# Out:
# [[7 7 7 7 7]
#  [3 7 7 7 3]
#  [7 5 7 7 7]]

# %% [markdown]
# ## Shuffle
#     The shuffle() method makes changes to the original array.

# %%
arr = np.array([1, 2, 3, 4, 5])
random.shuffle(arr)
print(arr)
# Out:
# [5 1 3 4 2]

# %%
arr = np.array([1, 2, 3, 4, 5])
print(random.permutation(arr))
# The permutation() method returns a re-arranged array (and leaves the original array un-changed).
# Out:
# [4 1 2 5 3]

# %%
arr = np.array([1, 2, 3, 4, 5])
new_arr = random.permutation(arr)

print('original array:', arr)
print('new array:', new_arr)
# Out:
# original array: [1 2 3 4 5]
# new array: [3 5 4 1 2]

# %% [markdown]
# ## Seaborn

# %%
# !pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0, 1, 2, 3, 4, 5], hist=False)

plt.show()
# Out:
# C:\Users\aashi\AppData\Local\Temp\ipykernel_15568\2406393504.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5], hist=False)

# %% [markdown]
# ## Normal Distribution

# %%
x = random.normal()
print(x)
# Out:
# -2.6130593771809134

# %%
x = random.normal(size = [2,3])
print(x)
# Out:
# [[-0.98894951 -0.89862538 -0.74867343]
#  [-0.13138039 -0.36987993  0.42071661]]

# %%
# loc - (Mean) where the peak of the bell exists.
# scale - (Standard Deviation) how flat the graph distribution should be.
# size - The shape of the returned array.

# %%
x = random.normal(loc=1, scale=2, size=(2, 3))
print(x)
# Out:
# [[ 2.65929213 -0.81917319  2.36885291]
#  [ 1.61502345  2.38057265  3.29249755]]

# %%
sns.displot(random.normal(size=100))
plt.show()

# %%
sns.distplot(random.normal(size=1000), hist=False)
plt.show()
# Out:
# C:\Users\aashi\AppData\Local\Temp\ipykernel_15568\1308901639.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000), hist=False)

# %% [markdown]
# ## binomial distribution

# %%
# n - number of trials.
# p - probability of occurence of each trial (e.g. for toss of a coin 0.5 each).
# size - The shape of the returned array.

# %%
x = random.binomial(n=10, p=0.5, size=10)
print(x)
# Out:
# [5 5 2 6 4 4 6 4 4 3]

# %%
bd = random.binomial(n=10, p=0.5, size=[2,3])
print(bd)
# Out:
# [[6 7 6]
#  [4 5 5]]

# %%
bd = random.binomial(n=10, p=0.5, size=1000)         # chneg size to 10, 100 and note the changes
sns.distplot(bd, hist=True, kde=False)

plt.show()
# Out:
# C:\Users\aashi\AppData\Local\Temp\ipykernel_15568\1154620743.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(bd, hist=True, kde=False)

# %%
# difference between binomial and normal distribution
sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')
plt.legend()
plt.show()
# Out:
# C:\Users\aashi\AppData\Local\Temp\ipykernel_15568\257595456.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
# C:\Users\aashi\AppData\Local\Temp\ipykernel_15568\257595456.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')

# %% [markdown]
# ##  Poisson Distribution

# %%
# lam - rate or known number of occurrences e.g. 2 for above problem.
# size - The shape of the returned array.

x = random.poisson(lam=2, size=10)
print(x)
# Out:
# [2 2 1 1 1 4 3 2 2 3]

# %%
sns.distplot(random.poisson(lam=2, size=1000), kde=False)

plt.show()
# Out:
# C:\Users\aashi\AppData\Local\Temp\ipykernel_15568\3265260757.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.poisson(lam=2, size=1000), kde=False)

# %%
sns.distplot(random.normal(loc=50, scale=7, size=1000), hist=False, label='normal')
sns.distplot(random.poisson(lam=50, size=1000), hist=False, label='poisson')
sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')
plt.legend()
plt.show()
# Out:
# C:\Users\aashi\AppData\Local\Temp\ipykernel_15568\112918725.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=7, size=1000), hist=False, label='normal')
# C:\Users\aashi\AppData\Local\Temp\ipykernel_15568\112918725.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.poisson(lam=50, size=1000), hist=False, label='poisson')
# C:\Users\aashi\AppData\Local\Temp\ipykernel_15568\112918725.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')

# %% [markdown]
# ## Uniform Distribution

# %%
# a - lower bound - default 0 .0.
# b - upper bound - default 1.0.
# size - The shape of the returned array.

x = random.uniform(size=(2, 3))
print(x)
# Out:
# [[0.0639349  0.91147782 0.00955333]
#  [0.22632048 0.41680895 0.77143427]]

# %%
x = random.uniform(size = 1000)
print(x)
sns.distplot(x, hist=False)
plt.show()
# Out:
# [0.7162788  0.59027484 0.2757507  0.55091567 0.41231471 0.0673087
#  0.51324419 0.90831756 0.0713789  0.45842706 0.07560651 0.28220388
#  0.87132327 0.76740367 0.40423979 0.25069038 0.24895088 0.26450949
#  0.57972545 0.16317663 0.56260722 0.237438   0.35153429 0.52303486
#  0.91511544 0.47487472 0.14977596 0.33409785 0.80027023 0.63985635
#  0.61457568 0.24796122 0.47450461 0.00956663 0.93047935 0.42352867
#  0.29960667 0.08020915 0.11550203 0.69122136 0.04756634 0.00738606
#  0.15624858 0.52680768 0.67835913 0.20207655 0.72987313 0.94679599
#  0.57641882 0.58296903 0.66038    0.01165076 0.53049664 0.62668091
#  0.19948777 0.24855526 0.34572133 0.77351845 0.86724347 0.48944996
#  0.32437452 0.53407275 0.96650106 0.42692433 0.81393823 0.54979352
#  0.45285794 0.33025342 0.23423289 0.97161312 0.7836845  0.24160192
#  0.47630356 0.1504753  0.05335313 0.43189989 0.01870826 0.69821639
#  0.76201109 0.30784062 0.17469721 0.63252678 0.49434706 0.38538636
#  0.29752851 0.99269729 0.66938651 0.67002775 0.84005219 0.01240065
#  0.37633367 0.23755737 0.95894004 0.95952155 0.60976578 0.60116616
#  0.00931797 0.47570101 0.60713725 0.30324891 0.29218338 0.42387573
#  0.6069514  0.91123886 0.57504967 0.7289478  0.03700045 0.84507438
#  0.77331025 0.2370006  0.61435716 0.85751273 0.93527443 0.30346632
#  0.19991109 0.1092414  0.21508509 0.30621506 0.45540969 0.19412584
#  0.35854901 0.82461253 0.76773528 0.85576493 0.53065784 0.10416653
#  0.64095044 0.01504432 0.67094845 0.44421836 0.67789316 0.17115148
#  0.13736264 0.2258507  0.59877108 0.3816418  0.87493003 0.70394661
#  0.32610713 0.45957653 0.39347457 0.24560777 0.72894598 0.51089137
#  0.99609144 0.25819248 0.01599204 0.92049872 0.53505654 0.81816151
#  0.47487191 0.33735872 0.87378785 0.54590461 0.76175969 0.19562982
#  0.61913243 0.47267604 0.2483714  0.80298709 0.24502267 0.46463986
#  0.05859366 0.22601176 0.58712855 0.49719982 0.69347844 0.12619778
#  0.24995256 0.09635277 0.55872422 0.36779899 0.50015052 0.51500662
#  0.31804643 0.51029614 0.55024009 0.57498507 0.5744465  0.50393171
#  0.9797699  0.13809846 0.59403164 0.50978709 0.88805559 0.00863352
#  0.65435589 0.4867687  0.63887892 0.17654297 0.33785567 0.62965539
#  0.64807903 0.12846573 0.05503415 0.57929827 0.58400392 0.10771988
#  0.85355837 0.18427269 0.79549722 0.87574735 0.07102681 0.71200309
#  0.13377924 0.88826789 0.39666574 0.42470367 0.54392811 0.42750479
#  0.49680951 0.99216575 0.40659958 0.04636952 0.61717979 0.81075296
#  0.23640283 0.99577592 0.99733526 0.92832655 0.65219885 0.57771741
#  0.8756653  0.14886777 0.45640584 0.16130531 0.90941375 0.76214577
#  0.57238246 0.35892304 0.30932619 0.49864153 0.04474169 0.63781756
#  0.31819504 0.709869   0.06825811 0.23608638 0.60384482 0.6263855
#  0.03839329 0.60698396 0.15411327 0.86162683 0.99417021 0.0606729
#  0.54699286 0.44807344 0.51397492 0.17854339 0.22674042 0.34695749
#  0.79487883 0.11118995 0.8073668  0.98456789]
# C:\Users\aashi\AppData\Local\Temp\ipykernel_15568\3433040914.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, hist=False)

# %% [markdown]
# ## Logistic Distribution

# %%
# loc - mean, where the peak is. Default 0.
# scale - standard deviation, the flatness of distribution. Default 1.
# size - The shape of the returned array.

x = random.logistic(loc=1, scale=2, size=(2, 3))
print(x)
# Out:
# [[ 3.14102506 -4.9010313  -1.66196162]
#  [ 2.48724602 -1.82405814 -0.0199818 ]]

# %%
sns.distplot(random.logistic(size=1000), hist=False)
plt.show()
# Out:
# C:\Users\aashi\AppData\Local\Temp\ipykernel_15568\1215292993.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.logistic(size=1000), hist=False)

# %%
sns.distplot(random.normal(scale=2, size=1000), hist=False, label='normal')
sns.distplot(random.logistic(size=1000), hist=False, label='logistic')
plt.legend()
plt.show()
# Out:
# C:\Users\aashi\AppData\Local\Temp\ipykernel_15568\3251732336.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(scale=2, size=1000), hist=False, label='normal')
# C:\Users\aashi\AppData\Local\Temp\ipykernel_15568\3251732336.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.logistic(size=1000), hist=False, label='logistic')

# %% [markdown]
# ## Multinomial distribution

# %%
x = random.multinomial(n=6, pvals=[1/6, 1/6, 1/6, 1/6, 1/6, 1/6])
print(x)
# Out:
# [1 1 2 0 1 1]
